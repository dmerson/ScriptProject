# %% [markdown]
# Read in character dialgoue file and look at columns.

# %%
#https://towardsdatascience.com/multi-class-text-classification-with-scikit-learn-12f1e60e0a9f
import pandas as pd
df = pd.read_csv('zootopia_dialogue.csv',encoding = "ISO-8859-1" )
df.head()
# Out:
#    Unnamed: 0                    current_character  \
# 0           1                          YOUNG JUDY
# 1           2                           YOUNG JUDY
# 2           3                          YOUNG JUDY
# 3           4                          YOUNG JUDY
# 4           5                      ASTRONAUT SHEEP
#
#                                     current_dialogue
# 0  Fear. Treachery. Bloodlust! Thousands of years...
# 1                               Blood, blood, blood!
# 2                                         And death.
# 3  And every young mammal has  multitudinous oppo...
# 4    Yeah, I don't have to cower in a  herd anymore.

# %% [markdown]
# Set only necessary columns from file.

# %%
from io import StringIO
col=['current_character','current_dialogue']
df=df[col]
df.head()
# Out:
#                      current_character  \
# 0                          YOUNG JUDY
# 1                           YOUNG JUDY
# 2                          YOUNG JUDY
# 3                          YOUNG JUDY
# 4                      ASTRONAUT SHEEP
#
#                                     current_dialogue
# 0  Fear. Treachery. Bloodlust! Thousands of years...
# 1                               Blood, blood, blood!
# 2                                         And death.
# 3  And every young mammal has  multitudinous oppo...
# 4    Yeah, I don't have to cower in a  herd anymore.

# %% [markdown]
# Remove any null values and trim away whitespace issues.

# %%
df=df[pd.notnull(df["current_character"])]
df=df[pd.notnull(df["current_dialogue"])]
df["current_character"]=df["current_character"].str.strip()
df["current_dialogue"]=df["current_dialogue"].str.strip()
df.head()
# Out:
#   current_character                                   current_dialogue
# 0        YOUNG JUDY  Fear. Treachery. Bloodlust! Thousands of years...
# 1        YOUNG JUDY                               Blood, blood, blood!
# 2        YOUNG JUDY                                         And death.
# 3        YOUNG JUDY  And every young mammal has  multitudinous oppo...
# 4   ASTRONAUT SHEEP    Yeah, I don't have to cower in a  herd anymore.

# %% [markdown]
# Factorize the target column

# %%
df['category_id'] = df['current_character'].factorize()[0]
df.head(10)
# Out:
#   current_character                                   current_dialogue  \
# 0        YOUNG JUDY  Fear. Treachery. Bloodlust! Thousands of years...
# 1        YOUNG JUDY                               Blood, blood, blood!
# 2        YOUNG JUDY                                         And death.
# 3        YOUNG JUDY  And every young mammal has  multitudinous oppo...
# 4   ASTRONAUT SHEEP    Yeah, I don't have to cower in a  herd anymore.
# 5   ASTRONAUT SHEEP                     Instead I can be an astronaut.
# 6    ACTUARY JAGUAR      I don't have to be a lonely hunter  any more.
# 7           ACTUARY  Today I can hunt for tax exemptions. I'm gonna...
# 8        YOUNG JUDY  And I can make the world a better  place! I am...
# 9        YOUNG JUDY                                  A police officer!
#
#    category_id
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# 5            1
# 6            2
# 7            3
# 8            0
# 9            0

# %% [markdown]
# Create a lookup table (category id)

# %%
category_id_df = df[['current_character', 'category_id']].drop_duplicates().sort_values('category_id')
category_id_df.head()
# Out:
#    current_character  category_id
# 0         YOUNG JUDY            0
# 4    ASTRONAUT SHEEP            1
# 6     ACTUARY JAGUAR            2
# 7            ACTUARY            3
# 10       GIDEON GREY            4

# %% [markdown]
# Create dictionaries for category

# %%
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'current_character']].values)
category_to_id
id_to_category
# Out:
# {0: 'YOUNG JUDY',
#  1: 'ASTRONAUT SHEEP',
#  2: 'ACTUARY JAGUAR',
#  3: 'ACTUARY',
#  4: 'GIDEON GREY',
#  5: 'STU HOPPS',
#  6: 'BONNIE HOPPS',
#  7: 'SHARLA',
#  8: 'TRAVIS THE WOLF HENCHMAN KID',
#  9: 'GARETH THE DOUBTING SHEEP BOY',
#  10: 'MAJOR FRIEDKIN',
#  11: 'LIONHEART',
#  12: 'BELLWETHER',
#  13: 'JUDY',
#  14: 'TRAIN CONDUCTOR',
#  15: 'COTTON',
#  16: 'CROWD OF BUNNIES',
#  17: 'GAZELLE',
#  18: 'DHARMA ARMADILLO',
#  19: 'HOPPS',
#  20: 'KUDU POOTOSSER',
#  21: 'ORYX POOTOSSER',
#  22: 'LEOPARD',
#  23: 'CLAWHAUSER',
#  24: 'OFFICER HIGGINS',
#  25: 'BOGO',
#  26: 'TRUCK DRIVER',
#  27: 'NICK',
#  28: 'WE RESERVE THE RIGHT TO REFUSE',
#  29: 'ELEPHANT',
#  30: 'MOUSE CONSTRUCTION WORKER',
#  31: 'FINNICK',
#  32: 'MOOSE',
#  33: 'ANGRY GERBIL LADY',
#  34: 'HIPPO CHILD',
#  35: 'ANGRY DRIVER',
#  36: 'FRANTIC PIG',
#  37: 'DUKE WEASELTON',
#  38: 'MCHORN',
#  39: 'FRU FRU SHREW',
#  40: 'MRS. OTTERTON',
#  41: 'YAX THE HIPPIE YAK',
#  42: 'NANGI',
#  43: 'YAX',
#  44: 'FLASH',
#  45: 'PRISCILLA',
#  46: 'MR. BIG',
#  47: 'MANCHAS',
#  48: 'ZP...',
#  49: 'MEAN KID ANIMAL',
#  50: 'YOUNG NICK',
#  51: 'NICK                          HOPPS',
#  52: 'WOLF GUARD',
#  53: 'GARY THE WOLF GUARD',
#  54: 'BADGER DOCTOR',
#  55: 'PRESS',
#  56: 'REPORTER',
#  57: 'REPORTER 2',
#  58: 'ANOTHER REPORTER',
#  59: 'REPORTER 3',
#  60: 'REPORTER 4',
#  61: 'REPORTER 5',
#  62: 'REPORTER 6',
#  63: 'REPORTERS',
#  64: 'FEMALE BOBCAT NEWS ANCHOR',
#  65: 'MALE MOOSE NEWS ANCHOR',
#  66: 'PIG',
#  67: 'RABBIT MOM',
#  68: 'HOPPS.',
#  69: 'ADULT GIDEON GREY',
#  70: 'RABBIT KID',
#  71: 'DOUG',
#  72: 'WOOLTER',
#  73: 'JESSE',
#  74: 'PREDATOR ANCHOR',
#  75: 'PREY ANCHOR',
#  76: 'PRED ANCHOR'}

# %% [markdown]
# Show a picture of number of categories

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
df.groupby('current_character').current_dialogue.count().plot.bar(ylim=0)
plt.show()

# %% [markdown]
# Calculate a tdidf frequency for dialogue

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(df.current_dialogue).toarray()
labels = df.category_id
features.shape
# Out:
# (892, 167)

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for current_character, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(current_character))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'ACTUARY':
#   . Most correlated unigrams:
# . oh
# . gonna
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'ACTUARY JAGUAR':
#   . Most correlated unigrams:
# . oh
# . don
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'ADULT GIDEON GREY':
#   . Most correlated unigrams:
# . word
# . family
#   . Most correlated bigrams:
# . officer hopps
# . night howlers
# # 'ANGRY DRIVER':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'ANGRY GERBIL LADY':
#   . Most correlated unigrams:
# . yeah
# . real
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'ANOTHER REPORTER':
#   . Most correlated unigrams:
# . predators
# . going
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'ASTRONAUT SHEEP':
#   . Most correlated unigrams:
# . don
# . yeah
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'BADGER DOCTOR':
#   . Most correlated unigrams:
# . time
# . lionheart
#   . Most correlated bigrams:
# . officer hopps
# . chief bogo
# # 'BELLWETHER':
#   . Most correlated unigrams:
# . really
# . judy
#   . Most correlated bigrams:
# . bye bye
# . officer hopps
# # 'BOGO':
#   . Most correlated unigrams:
# . badge
# . hopps
#   . Most correlated bigrams:
# . officer hopps
# . emmitt otterton
# # 'BONNIE HOPPS':
#   . Most correlated unigrams:
# . job
# . yeah
#   . Most correlated bigrams:
# . meter maid
# . bye bye
# # 'CLAWHAUSER':
#   . Most correlated unigrams:
# . wait
# . thought
#   . Most correlated bigrams:
# . officer hopps
# . chief bogo
# # 'COTTON':
#   . Most correlated unigrams:
# . bye
# . love
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'CROWD OF BUNNIES':
#   . Most correlated unigrams:
# . oh
# . bye
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'DHARMA ARMADILLO':
#   . Most correlated unigrams:
# . oh
# . don
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'DOUG':
#   . Most correlated unigrams:
# . better
# . got
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'DUKE WEASELTON':
#   . Most correlated unigrams:
# . come
# . make
#   . Most correlated bigrams:
# . officer hopps
# . night howlers
# # 'ELEPHANT':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'FEMALE BOBCAT NEWS ANCHOR':
#   . Most correlated unigrams:
# . bad
# . fear
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'FINNICK':
#   . Most correlated unigrams:
# . good
# . ll
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'FLASH':
#   . Most correlated unigrams:
# . sure
# . humped
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'FRANTIC PIG':
#   . Most correlated unigrams:
# . bunny
# . talking
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'FRU FRU SHREW':
#   . Most correlated unigrams:
# . hi
# . aw
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'GARETH THE DOUBTING SHEEP BOY':
#   . Most correlated unigrams:
# . judy
# . bad
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'GARY THE WOLF GUARD':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'GAZELLE':
#   . Most correlated unigrams:
# . predators
# . zootopia
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'GIDEON GREY':
#   . Most correlated unigrams:
# . little
# . dumb
#   . Most correlated bigrams:
# . officer hopps
# . dumb bunny
# # 'HIPPO CHILD':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'HOPPS':
#   . Most correlated unigrams:
# . mr
# . nick
#   . Most correlated bigrams:
# . yes yes
# . run plate
# # 'HOPPS.':
#   . Most correlated unigrams:
# . oh
# . fine
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'JESSE':
#   . Most correlated unigrams:
# . oh
# . stop
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'JUDY':
#   . Most correlated unigrams:
# . guys
# . bye
#   . Most correlated bigrams:
# . officer hopps
# . gideon grey
# # 'KUDU POOTOSSER':
#   . Most correlated unigrams:
# . meter
# . shut
#   . Most correlated bigrams:
# . officer hopps
# . meter maid
# # 'LEOPARD':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'LIONHEART':
#   . Most correlated unigrams:
# . mayor
# . bellwether
#   . Most correlated bigrams:
# . chief bogo
# . don know
# # 'MAJOR FRIEDKIN':
#   . Most correlated unigrams:
# . oh
# . bunny
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'MALE MOOSE NEWS ANCHOR':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'MANCHAS':
#   . Most correlated unigrams:
# . okay
# . howlers
#   . Most correlated bigrams:
# . officer hopps
# . night howlers
# # 'MCHORN':
#   . Most correlated unigrams:
# . got
# . big
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'MEAN KID ANIMAL':
#   . Most correlated unigrams:
# . aw
# . fox
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'MOOSE':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'MOUSE CONSTRUCTION WORKER':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'MR. BIG':
#   . Most correlated unigrams:
# . em
# . ice
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'MRS. OTTERTON':
#   . Most correlated unigrams:
# . thank
# . emmitt
#   . Most correlated bigrams:
# . chief bogo
# . emmitt otterton
# # 'NANGI':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'NICK':
#   . Most correlated unigrams:
# . flash
# . carrots
#   . Most correlated bigrams:
# . real cop
# . toot toot
# # 'NICK                          HOPPS':
#   . Most correlated unigrams:
# . like
# . stop
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'OFFICER HIGGINS':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'ORYX POOTOSSER':
#   . Most correlated unigrams:
# . yeah
# . shut
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'PIG':
#   . Most correlated unigrams:
# . oh
# . predator
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'PRED ANCHOR':
#   . Most correlated unigrams:
# . say
# . night
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'PREDATOR ANCHOR':
#   . Most correlated unigrams:
# . mayor
# . bellwether
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'PRESS':
#   . Most correlated unigrams:
# . predators
# . protect
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'PREY ANCHOR':
#   . Most correlated unigrams:
# . protect
# . lionheart
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'PRISCILLA':
#   . Most correlated unigrams:
# . yes
# . flash
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'RABBIT KID':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'RABBIT MOM':
#   . Most correlated unigrams:
# . oh
# . come
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'REPORTER':
#   . Most correlated unigrams:
# . mean
# . course
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'REPORTER 2':
#   . Most correlated unigrams:
# . oh
# . okay
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'REPORTER 3':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'REPORTER 4':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'REPORTER 5':
#   . Most correlated unigrams:
# . officer
# . predator
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'REPORTER 6':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'REPORTERS':
#   . Most correlated unigrams:
# . oh
# . savage
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'SHARLA':
#   . Most correlated unigrams:
# . tickets
# . gideon
#   . Most correlated bigrams:
# . officer hopps
# . gideon grey
# # 'STU HOPPS':
#   . Most correlated unigrams:
# . maid
# . sure
#   . Most correlated bigrams:
# . real cop
# . meter maid
# # 'TRAIN CONDUCTOR':
#   . Most correlated unigrams:
# . oh
# . zootopia
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'TRAVIS THE WOLF HENCHMAN KID':
#   . Most correlated unigrams:
# . pretty
# . scared
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'TRUCK DRIVER':
#   . Most correlated unigrams:
# . fox
# . going
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'WE RESERVE THE RIGHT TO REFUSE':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'WOLF GUARD':
#   . Most correlated unigrams:
# . oh
# . gonna
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'WOOLTER':
#   . Most correlated unigrams:
# . stop
# . hey
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'YAX':
#   . Most correlated unigrams:
# . sure
# . nangi
#   . Most correlated bigrams:
# . officer hopps
# . emmitt otterton
# # 'YAX THE HIPPIE YAK':
#   . Most correlated unigrams:
# . huh
# . nangi
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'YOUNG JUDY':
#   . Most correlated unigrams:
# . gideon
# . world
#   . Most correlated bigrams:
# . gideon grey
# . better place
# # 'YOUNG NICK':
#   . Most correlated unigrams:
# . did
# . pretty
#   . Most correlated bigrams:
# . don know
# . officer hopps
# # 'ZP...':
#   . Most correlated unigrams:
# . just
# . oh
#   . Most correlated bigrams:
# . don know
# . officer hopps

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(df['current_dialogue'], df['current_character'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
    cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\tf35\lib\site-packages\sklearn\model_selection\_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\ProgramData\Anaconda3\envs\tf35\lib\site-packages\sklearn\model_selection\_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\ProgramData\Anaconda3\envs\tf35\lib\site-packages\sklearn\model_selection\_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# C:\ProgramData\Anaconda3\envs\tf35\lib\site-packages\sklearn\model_selection\_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.284453
# LogisticRegression        0.340110
# MultinomialNB             0.325938
# RandomForestClassifier    0.333895
# Name: accuracy, dtype: float64

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',xticklabels=category_id_df.current_character.values, yticklabels=category_id_df.current_character.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from IPython.display import display
for predicted in category_id_df.category_id:
    for actual in category_id_df.category_id:
        if predicted != actual and conf_mat[actual, predicted] >= 10:
            print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
            display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['current_character', 'current_dialogue']])
            print('')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-d58db619cd2e> in <module>()
#       2 for predicted in category_id_df.category_id:
#       3     for actual in category_id_df.category_id:
# ----> 4         if predicted != actual and conf_mat[actual, predicted] >= 10:
#       5             print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
#       6             display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['current_character', 'current_dialogue']])
#
# IndexError: index 48 is out of bounds for axis 0 with size 48

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, target_names=df['current_character'].unique()))
# Out:
#                                      precision    recall  f1-score   support
#
#                          YOUNG JUDY       0.00      0.00      0.00         9
#                     ASTRONAUT SHEEP       0.00      0.00      0.00         1
#                      ACTUARY JAGUAR       0.00      0.00      0.00         5
#                             ACTUARY       0.14      0.20      0.17        10
#                         GIDEON GREY       0.00      0.00      0.00         8
#                           STU HOPPS       0.00      0.00      0.00         2
#                        BONNIE HOPPS       0.00      0.00      0.00         2
#                              SHARLA       0.00      0.00      0.00         1
#        TRAVIS THE WOLF HENCHMAN KID       0.00      0.00      0.00         5
#       GARETH THE DOUBTING SHEEP BOY       0.11      0.22      0.15         9
#                      MAJOR FRIEDKIN       0.00      0.00      0.00         4
#                           LIONHEART       0.00      0.00      0.00         1
#                          BELLWETHER       0.00      0.00      0.00         1
#                                JUDY       0.37      0.66      0.47        99
#                     TRAIN CONDUCTOR       0.00      0.00      0.00         1
#                              COTTON       0.00      0.00      0.00         2
#                    CROWD OF BUNNIES       0.00      0.00      0.00         1
#                             GAZELLE       0.00      0.00      0.00         8
#                    DHARMA ARMADILLO       0.38      0.14      0.20        22
#                               HOPPS       0.27      0.26      0.26        47
#                      KUDU POOTOSSER       0.00      0.00      0.00         1
#                      ORYX POOTOSSER       0.00      0.00      0.00         1
#                             LEOPARD       0.00      0.00      0.00         2
#                          CLAWHAUSER       0.00      0.00      0.00         1
#                     OFFICER HIGGINS       0.00      0.00      0.00         1
#                                BOGO       0.00      0.00      0.00         1
#                        TRUCK DRIVER       0.00      0.00      0.00         6
#                                NICK       0.00      0.00      0.00         0
#      WE RESERVE THE RIGHT TO REFUSE       0.50      0.33      0.40         3
#                            ELEPHANT       0.00      0.00      0.00         5
#           MOUSE CONSTRUCTION WORKER       0.00      0.00      0.00         3
#                             FINNICK       0.00      0.00      0.00         2
#                               MOOSE       0.00      0.00      0.00        12
#                   ANGRY GERBIL LADY       0.00      0.00      0.00         6
#                         HIPPO CHILD       0.00      0.00      0.00         1
#                        ANGRY DRIVER       0.00      0.00      0.00         1
#                         FRANTIC PIG       0.00      0.00      0.00         0
#                      DUKE WEASELTON       0.00      0.00      0.00         1
#                              MCHORN       0.00      0.00      0.00         2
#                       FRU FRU SHREW       0.00      0.00      0.00         1
#                       MRS. OTTERTON       0.00      0.00      0.00         1
#                  YAX THE HIPPIE YAK       0.00      0.00      0.00         0
#                               NANGI       0.00      0.00      0.00         1
#                                 YAX       0.00      0.00      0.00         2
#                               FLASH       0.00      0.00      0.00         1
#                           PRISCILLA       0.00      0.00      0.00         1
#                             MR. BIG       0.00      0.00      0.00         1
#                             MANCHAS       0.00      0.00      0.00         0
#
#                         avg / total       0.21      0.29      0.23       295
# C:\ProgramData\Anaconda3\envs\tf35\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\envs\tf35\lib\site-packages\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
